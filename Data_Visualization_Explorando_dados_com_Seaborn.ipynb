# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrealvees/Alura-DataScience/blob/master/Data_Visualization_Explorando_dados_com_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Importando os dados

# %% [markdown]
# ## Tópico 1 - Introdução

# %%
#importando o arquivo
import pandas as pd
dados = pd.read_csv('/content/drive/My Drive/ArquivosPython/tips.csv')

# %% [markdown]
# ## Tópico 2 - Importando os dados

# %%
#cabeçaalho dos arquivos
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %% [markdown]
# ## Tópico 2 -  Traduzindo colunas e campos

# %% [markdown]
# dados.columns
#
# renomear = {
#     'total_bill' : 'valor-da_conta',
#     'tip' : 'gorjeta',
#     'dessert' : 'sobremesa',
#     'day' : 'dia_da_semana',
#     'time' : 'hora_do_dia',
#     'size' : 'total_de_pessoas'
# }

# %%
dados.columns = ['valor_da_conta','gorjeta','sobremesa','dia_da_semana','hora_do_dia','total_de_pessoas']
dados
# Out:
#      valor_da_conta  gorjeta  ... hora_do_dia total_de_pessoas
# 0             16.99     1.01  ...      Dinner                2
# 1             10.34     1.66  ...      Dinner                3
# 2             21.01     3.50  ...      Dinner                3
# 3             23.68     3.31  ...      Dinner                2
# 4             24.59     3.61  ...      Dinner                4
# ..              ...      ...  ...         ...              ...
# 239           29.03     5.92  ...      Dinner                3
# 240           27.18     2.00  ...      Dinner                2
# 241           22.67     2.00  ...      Dinner                2
# 242           17.82     1.75  ...      Dinner                2
# 243           18.78     3.00  ...      Dinner                2
#
# [244 rows x 6 columns]

# %%
#renomear = {
    'total_bill' : 'valor-da_conta',
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia',
    'size' : 'total_de_pessoas'
}
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas = dados
gorjetas
# Out:
#      valor_da_conta  gorjeta  ... hora_do_dia total_de_pessoas
# 0             16.99     1.01  ...      Dinner                2
# 1             10.34     1.66  ...      Dinner                3
# 2             21.01     3.50  ...      Dinner                3
# 3             23.68     3.31  ...      Dinner                2
# 4             24.59     3.61  ...      Dinner                4
# ..              ...      ...  ...         ...              ...
# 239           29.03     5.92  ...      Dinner                3
# 240           27.18     2.00  ...      Dinner                2
# 241           22.67     2.00  ...      Dinner                2
# 242           17.82     1.75  ...      Dinner                2
# 243           18.78     3.00  ...      Dinner                2
#
# [244 rows x 6 columns]

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# criando dicionario de dados
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
# Mapeando os dados na coluna 
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta  ... hora_do_dia total_de_pessoas
# 0           16.99     1.01  ...      Dinner                2
#
# [1 rows x 6 columns]

# %%
# SEtando os dados no DATAFRAME
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta  ... hora_do_dia total_de_pessoas
# 0           16.99     1.01  ...      Dinner                2
#
# [1 rows x 6 columns]

# %%
dias = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana.map(dias)
# Out:
# 0      Domingo
# 1      Domingo
# 2      Domingo
# 3      Domingo
# 4      Domingo
#         ...
# 239     Sábado
# 240     Sábado
# 241     Sábado
# 242     Sábado
# 243     Quinta
# Name: dia_da_semana, Length: 244, dtype: object

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
hora = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia.map(hora)
# Out:
# 0      Jantar
# 1      Jantar
# 2      Jantar
# 3      Jantar
# 4      Jantar
#         ...
# 239    Jantar
# 240    Jantar
# 241    Jantar
# 242    Jantar
# 243    Jantar
# Name: hora_do_dia, Length: 244, dtype: object

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta  ... hora_do_dia total_de_pessoas
# 0           16.99     1.01  ...      Jantar                2
# 1           10.34     1.66  ...      Jantar                3
# 2           21.01     3.50  ...      Jantar                3
# 3           23.68     3.31  ...      Jantar                2
# 4           24.59     3.61  ...      Jantar                4
#
# [5 rows x 6 columns]

# %% [markdown]
# # Aula 2 - Comparando distribuições de maneira exploratória

# %% [markdown]
# ##Tópico 1 - Seaborn e scatterplot

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.scatterplot(x= 'valor_da_conta', y= 'gorjeta', data=gorjetas)

# %%
valor_gorjeta = sns.scatterplot(x= 'valor_da_conta', y= 'gorjeta', data=gorjetas)

# %% [markdown]
# ** Visualmente o valor da gorjeta aumenta conforme o valor da conta aumenta

# %%
print('A base de dados contém {} registros'.format(gorjetas.shape[0]))
# Out:
# A base de dados contém 244 registros

# %%
print('A base de dados contém {} registros \n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ##Tópico 2 - Coluna porcentagem

# %%
#Criando a coluna gorjetas
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']

# %%
#Arredodando a coluna gorjeta
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta  ... total_de_pessoas porcentagem
# 0             16.99     1.01  ...                2        0.06
# 1             10.34     1.66  ...                3        0.16
# 2             21.01     3.50  ...                3        0.17
# 3             23.68     3.31  ...                2        0.14
# 4             24.59     3.61  ...                4        0.15
# ..              ...      ...  ...              ...         ...
# 239           29.03     5.92  ...                3        0.20
# 240           27.18     2.00  ...                2        0.07
# 241           22.67     2.00  ...                2        0.09
# 242           17.82     1.75  ...                2        0.10
# 243           18.78     3.00  ...                2        0.16
#
# [244 rows x 7 columns]

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# ## Tópico 3 - Relplot e Implot

# %%
# Grafíco categorico pelas gorjtas
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind='line', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# # Aula 3 - Analisando de forma visual e descritiva

# %% [markdown]
# ##Tópico 1 - Análise descritiva

# %%
#Analisando as gorjetas em relação a sobremesa
# Pediram Sobremesa
gorjetas[gorjetas.sobremesa == 'Sim']
# Out:
#      valor_da_conta  gorjeta  ... total_de_pessoas porcentagem
# 56            38.01     3.00  ...                4        0.08
# 58            11.24     1.76  ...                2        0.16
# 60            20.29     3.21  ...                2        0.16
# 61            13.81     2.00  ...                2        0.14
# 62            11.02     1.98  ...                2        0.18
# ..              ...      ...  ...              ...         ...
# 234           15.53     3.00  ...                2        0.19
# 236           12.60     1.00  ...                2        0.08
# 237           32.83     1.17  ...                2        0.04
# 240           27.18     2.00  ...                2        0.07
# 241           22.67     2.00  ...                2        0.09
#
# [93 rows x 7 columns]

# %%
gorjetas[gorjetas.sobremesa == 'Não']
# Out:
#      valor_da_conta  gorjeta  ... total_de_pessoas porcentagem
# 0             16.99     1.01  ...                2        0.06
# 1             10.34     1.66  ...                3        0.16
# 2             21.01     3.50  ...                3        0.17
# 3             23.68     3.31  ...                2        0.14
# 4             24.59     3.61  ...                4        0.15
# ..              ...      ...  ...              ...         ...
# 235           10.07     1.25  ...                2        0.12
# 238           35.83     4.67  ...                3        0.13
# 239           29.03     5.92  ...                3        0.20
# 242           17.82     1.75  ...                2        0.10
# 243           18.78     3.00  ...                2        0.16
#
# [151 rows x 7 columns]

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %% [markdown]
# ## Aula 2 -  Análise visual

# %%
#Analise das sobremesas
sns.catplot(x='sobremesa', y='gorjeta', data=gorjetas)

# %%
#Quem pediu sobremesa e quem Não pediu
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
#Analisando as sobremesas
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', data=gorjetas)

# %%
#Grafíco por linhas
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# visualmente, identificaremos que aqueles que pediram sobremesa possuem a distribuição diferente em comparação aos que não pediram.

# %% [markdown]
# ## Tópico 3 - Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**
#
# **H<sup>alt</sup>**.
#
# >**A distribuição da taxa da gorjeta não é a mesma nos dois grupos**

# %%
#importando a biblioteca para construit as ipotéses
from scipy.stats import ranksums

# %%
#Porcetagem de todo mundo que pediu sobremesa
gorjetas.query("sobremesa == 'Sim'").porcentagem
# Out:
# 56     0.08
# 58     0.16
# 60     0.16
# 61     0.14
# 62     0.18
#        ...
# 234    0.19
# 236    0.08
# 237    0.04
# 240    0.07
# 241    0.09
# Name: porcentagem, Length: 93, dtype: float64

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
ranksums(sobremesa, sem_sobremesa)
# Out:
# RanksumsResult(statistic=-0.6331073145314825, pvalue=0.5266635660124415)

# %%
r = ranksums(sobremesa, sem_sobremesa)
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**

# %% [markdown]
# #Aula 4 - Comparando e explorando os dias da semana

# %% [markdown]
# ## Tópico 1 - Dias da semana

# %%
#Analise pelo dia da seman
sns.catplot(x='dia_da_semana', y='valor_da_conta', data=gorjetas)

# %%
#Dias da semana como  relplot
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=gorjetas)

# %%
#Dias da semana como  relplot
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %% [markdown]
# ## Tópico 2 -  Análise descritiva

# %%
media_geral_gorjeta = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas é de {}'.format(media_geral_gorjeta))
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
# media dos dias da semana 
gorjetas.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105     0.166974
# Quinta              17.682742  2.771452          2.451613     0.161129
# Sexta               17.151579  2.734737          2.105263     0.169474
# Sábado              20.441379  2.993103          2.517241     0.153678

# %%
# Analise Descritiva
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
gorjetas.dia_da_semana.value_counts()
# Out:
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ##Tópico 2 -  Teste de hipótese 2B

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição do valor da conta e igual no sabado e no domingo**
#
# **H<sup>alt</sup>**.
#
# >**A distribuição do valor da conta não e igual no sabado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo' ").valor_da_conta
valor_conta_domingo
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: valor_da_conta, Length: 76, dtype: float64

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta
valor_conta_sabado
# Out:
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
#        ...
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# Name: valor_da_conta, Length: 87, dtype: float64

# %%
ranksums(valor_conta_domingo, valor_conta_sabado)
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print('O valor do p-value é {}'.format(r2.pvalue))
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# O resultado de pvalue será 0.35, ou seja, apenas aceitaremos a hipótese alternativa se este número for menor do que 0.05; como é maior, apenas nossa hipótese nula é válida.

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição do valor da conta e igual no sabado e no domingo**

# %% [markdown]
#  # Aula 5 - Distribuição de frequência e teste de hipótese

# %% [markdown]
# ## Tópico 1 - Distplot, boxplot e violinplot

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa  ... hora_do_dia total_de_pessoas  porcentagem
# 0           16.99     1.01       Não  ...      Jantar                2         0.06
# 1           10.34     1.66       Não  ...      Jantar                3         0.16
# 2           21.01     3.50       Não  ...      Jantar                3         0.17
# 3           23.68     3.31       Não  ...      Jantar                2         0.14
# 4           24.59     3.61       Não  ...      Jantar                4         0.15
#
# [5 rows x 7 columns]

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
# Plot para analisar almoço e janta
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm', data=gorjetas)

# %%
#violinplot
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
#BoxPlot
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)

# %%
sns.distplot(almoco, kde=False)

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.distplot(jantar)

# %%
sns.distplot(jantar, kde=False)

# %% [markdown]
# ## Tópico 2 -  Teste de hipótese 2

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição da conta e igual no almoço e no jantar**
#
# **H<sup>alt</sup>**.
#
# >**A distribuição da conta não é igual no almoço e no jantar**

# %%
#Média dos valores
gorjetas.groupby(['hora_do_dia']).mean()
# Out:
#              valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088          2.411765     0.163971
# Jantar            20.797159  3.102670          2.630682     0.159773

# %%
#retirando a coluna total+de_pessoas
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %%
ranksums(almoco,jantar)
# Out:
# RanksumsResult(statistic=-3.2438872807262955, pvalue=0.0011791039723641672)

# %%
#testando a hipotese
r2 = ranksums(jantar, almoco)
r2
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %% [markdown]
# **H<sup>alt</sup>**.
#
# >**A distribuição da conta não é igual no almoço e no jantar**

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição da taxa da gorjeta e igual no almoço e no jantar**
#
# **H<sup>alt</sup>**.
#
# >**A distribuição da taxa da gorjeta não e igual no almoço e no jantar**

# %%
#Porcentagem do almoço
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
#Porcentagem da janta
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
#Comparando as duas variaveis
ranksums(porcentagem_almoco, porcentagem_jantar)
# Out:
# RanksumsResult(statistic=1.1258018532735787, pvalue=0.2602493995587126)

# %%
#ranksums formatado
r3 = ranksums(porcentagem_almoco, porcentagem_jantar)
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 0.2602493995587126

# %% [markdown]
# **H<sup>null</sup>**.
#
# >**A distribuição da conta e igual no almoço e no jantar**
